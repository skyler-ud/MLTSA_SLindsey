# %% [markdown]
# <a href="https://colab.research.google.com/github/skyler-ud/FDSFE_SLindsey/blob/main/labs/2_27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as npn
import pylab as plt

# %%
N=100
np.random.seed(302)
y=np.random.randn(N)
plt.hist(y)
# Out:
# (array([ 4.,  7.,  4., 18., 17., 23., 14.,  9.,  2.,  2.]),
#  array([-2.67005842, -2.14052639, -1.61099437, -1.08146234, -0.55193032,
#         -0.02239829,  0.50713374,  1.03666576,  1.56619779,  2.09572982,
#          2.62526184]),
#  <BarContainer object of 10 artists>)

# %%
t=np.linspace(0,N,N)
t=t/N
plt.plot(t,y)

# %%
plt.hist(y[:50],alpha=0.4)
plt.hist(y[50:],alpha=0.4)
# Out:
# (array([ 2.,  3.,  2.,  9.,  4., 15.,  7.,  6.,  1.,  1.]),
#  array([-2.61504849, -2.09101745, -1.56698642, -1.04295539, -0.51892436,
#          0.00510668,  0.52913771,  1.05316874,  1.57719978,  2.10123081,
#          2.62526184]),
#  <BarContainer object of 10 artists>)
